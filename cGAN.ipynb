# %% [markdown]
# ## Libraries

# %%
import sys
sys.path.append('./venv/lib/python3.6/site-packages')

# %%
import os
import time
import random

import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image

# %%
import torch
from torch import nn
from torch import optim
from torchvision import transforms as vtransforms
from torchvision import utils as vutils
from torchvision import datasets

# %%
from gans.utils.data import CartoonSet
from gans.utils.layers import *
from gans.utils.functions import *
from gans.models import *
from gans.trainer import *

# %% [markdown]
# ## Random seed

# %%
# Set random seem for reproducibility
manualSeed = 999
#manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)
# Out:
# Random Seed:  999

# %% [markdown]
# ## Inputs

# %%
# Dataset
data_root = './datasets'
# data_name = 'CartoonSet'
data_name = 'FashionMNIST'
# data_name = 'MNIST'

batch_size = 200
sample_size = 50
nrow = 5

num_epochs = 50

num_workers = 8


# Output dir
output_root = './output/CGAN'
# overwrite real sample output
overwrite_real = False

noize_dim = 100

# Optimization parameters
lr = 0.001
beta1 = 0.5

# %% [markdown]
# ## Device

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print('using device: ', device)
# Out:
# using device:  cuda:0

# %% [markdown]
# ## Dataset

# %%
img_size = 28
in_channels = 1

if data_name == 'CartoonSet':
    img_size = 75
    dataset = CartoonSet(root=os.path.join(data_root, data_name), 
                         transform=vtransforms.Compose([
                             vtransforms.CenterCrop(size=400),
                             vtransforms.Resize(size=img_size), 
                             vtransforms.ToTensor(),
                             vtransforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5)),
                         ]))
    
elif data_name == 'MNIST':
    dataset = datasets.MNIST(root=os.path.join(data_root, data_name), 
                             download=True,
                             transform=vtransforms.Compose([
                                 vtransforms.ToTensor(),
                                 vtransforms.Normalize((0.5,), (0.5,)),
                         ]))
elif data_name == 'FashionMNIST':
    dataset = datasets.FashionMNIST(root=os.path.join(data_root, data_name), 
                                    download=True,
                                    transform=vtransforms.Compose([
                                        vtransforms.ToTensor(),
                                        vtransforms.Normalize((0.5,), (0.5,)),
                                    ]))
    
dtype = dataset[0][0].dtype
img_shape = dataset[0][0].shape

# %% [markdown]
# ## Dataloader

# %%
dataloader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         shuffle=True, 
                                         num_workers=num_workers)

# %%
if not os.path.exists(os.path.join(output_root, data_name)):
    os.makedirs(os.path.join(output_root, data_name))

real_sample_path = os.path.join(output_root, data_name, 'real_samples.png')


real_batch = next(iter(dataloader))

vutils.save_image(real_batch[0], real_sample_path, 
                  normalize=True, range=(0,1), nrow=nrow)
Image(real_sample_path)

# %% [markdown]
# ## Model

# %%
C, H, W = img_shape
features = C * H * W

# %%
layersG = [
    *linearBlock(noize_dim+10, 128, normalize=False, activation='ReLU'),
    *linearBlock(128, 256, activation='ReLU'),
    *linearBlock(256, 512, activation='ReLU'),
    *linearBlock(512, 1024, activation='ReLU'),
    *linearBlock(1024, features, normalize=False, activation='Tanh'),
]

netG = ConditionalGenerator(layers=layersG, img_shape=img_shape)
print(netG)
# Out:
# ConditionalGenerator(
#   (encoder): OneHotEncoder()
#   (model): Sequential(
#     (0): Linear(in_features=110, out_features=128, bias=True)
#     (1): ReLU(inplace)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU(inplace)
#     (8): Linear(in_features=512, out_features=1024, bias=True)
#     (9): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace)
#     (11): Linear(in_features=1024, out_features=784, bias=True)
#     (12): Tanh()
#     (13): Unflatten2d(img_shape=(1, 28, 28))
#   )
# )

# %%
layersD = [
    *linearBlock(features+10, 1024, normalize=False, activation='LeakyReLU'),
    *linearBlock(1024, 512, normalize=False, activation='LeakyReLU'),
    *linearBlock(512, 256, normalize=False, activation='LeakyReLU'),
    *linearBlock(256, 128, normalize=False, activation='LeakyReLU'),
    *linearBlock(128, 1, normalize=False, activation='Sigmoid'),
]

netD = ConditionalDiscriminator(layers=layersD)
print(netD)
# Out:
# ConditionalDiscriminator(
#   (flatten): Flatten()
#   (encoder): OneHotEncoder()
#   (model): Sequential(
#     (0): Linear(in_features=794, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace)
#     (2): Linear(in_features=1024, out_features=512, bias=True)
#     (3): LeakyReLU(negative_slope=0.2, inplace)
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace)
#     (6): Linear(in_features=256, out_features=128, bias=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace)
#     (8): Linear(in_features=128, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )

# %% [markdown]
# ## Training

# %%
y_fixed = torch.tensor([i//nrow for i in range(sample_size)], device=device)

# %%
trainer = CGANTrainer(generator=netG, discriminator=netD,
                     optimizer=optim.Adam, loss=nn.BCELoss(), y_fixed=y_fixed,
                     device=device, multi_gpu=False, output_path=os.path.join(output_root, data_name),
                     batch_size=batch_size, num_epochs=num_epochs, sample_size=sample_size)

# %%
trainer.train(dataloader=dataloader, nrow=nrow)
# Out:
# /home/shu/.local/lib/python3.6/site-packages/torch/nn/functional.py:2016: UserWarning: Using a target size (torch.Size([200])) that is different to the input size (torch.Size([200, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# [Epoch 0/50][Batch 0/300] Loss_D: 1.39 Loss_G: 0.70
# [Epoch 0/50][Batch 60/300] Loss_D: 1.48 Loss_G: 0.51
# [Epoch 0/50][Batch 120/300] Loss_D: 1.80 Loss_G: 2.07
# [Epoch 0/50][Batch 180/300] Loss_D: 1.16 Loss_G: 1.25
# [Epoch 0/50][Batch 240/300] Loss_D: 1.19 Loss_G: 1.03
# Epoch 0 running time: 14.61
# [Epoch 1/50][Batch 0/300] Loss_D: 1.00 Loss_G: 1.29
# [Epoch 1/50][Batch 60/300] Loss_D: 0.90 Loss_G: 1.32
# [Epoch 1/50][Batch 120/300] Loss_D: 0.95 Loss_G: 1.51
# [Epoch 1/50][Batch 180/300] Loss_D: 1.15 Loss_G: 1.28
# [Epoch 1/50][Batch 240/300] Loss_D: 1.23 Loss_G: 1.54
# Epoch 1 running time: 13.25
# [Epoch 2/50][Batch 0/300] Loss_D: 1.37 Loss_G: 0.89
# [Epoch 2/50][Batch 60/300] Loss_D: 1.06 Loss_G: 1.04
# [Epoch 2/50][Batch 120/300] Loss_D: 1.13 Loss_G: 1.14
# [Epoch 2/50][Batch 180/300] Loss_D: 1.12 Loss_G: 1.02
# [Epoch 2/50][Batch 240/300] Loss_D: 1.35 Loss_G: 0.88
# Epoch 2 running time: 12.74
# [Epoch 3/50][Batch 0/300] Loss_D: 1.20 Loss_G: 1.19
# [Epoch 3/50][Batch 60/300] Loss_D: 1.75 Loss_G: 1.03
# [Epoch 3/50][Batch 120/300] Loss_D: 1.30 Loss_G: 0.94
# [Epoch 3/50][Batch 180/300] Loss_D: 1.24 Loss_G: 1.54
# [Epoch 3/50][Batch 240/300] Loss_D: 1.37 Loss_G: 0.93
# Epoch 3 running time: 12.81
# [Epoch 4/50][Batch 0/300] Loss_D: 1.25 Loss_G: 0.94
# [Epoch 4/50][Batch 60/300] Loss_D: 1.15 Loss_G: 0.87
# [Epoch 4/50][Batch 120/300] Loss_D: 1.30 Loss_G: 0.96
# [Epoch 4/50][Batch 180/300] Loss_D: 1.36 Loss_G: 0.93
# [Epoch 4/50][Batch 240/300] Loss_D: 1.29 Loss_G: 0.95
# Epoch 4 running time: 14.16
# [Epoch 5/50][Batch 0/300] Loss_D: 1.57 Loss_G: 1.13
# [Epoch 5/50][Batch 60/300] Loss_D: 1.35 Loss_G: 0.87
# [Epoch 5/50][Batch 120/300] Loss_D: 1.39 Loss_G: 1.19
# [Epoch 5/50][Batch 180/300] Loss_D: 1.19 Loss_G: 0.92
# [Epoch 5/50][Batch 240/300] Loss_D: 1.25 Loss_G: 0.72
# Epoch 5 running time: 12.30
# [Epoch 6/50][Batch 0/300] Loss_D: 1.31 Loss_G: 0.85
# [Epoch 6/50][Batch 60/300] Loss_D: 1.24 Loss_G: 0.91
# [Epoch 6/50][Batch 120/300] Loss_D: 1.33 Loss_G: 0.86
# [Epoch 6/50][Batch 180/300] Loss_D: 1.33 Loss_G: 0.84
# [Epoch 6/50][Batch 240/300] Loss_D: 1.31 Loss_G: 0.67
# Epoch 6 running time: 13.05
# [Epoch 7/50][Batch 0/300] Loss_D: 1.33 Loss_G: 0.78
# [Epoch 7/50][Batch 60/300] Loss_D: 1.28 Loss_G: 1.02
# [Epoch 7/50][Batch 120/300] Loss_D: 1.27 Loss_G: 1.05
# [Epoch 7/50][Batch 180/300] Loss_D: 1.36 Loss_G: 0.85
# [Epoch 7/50][Batch 240/300] Loss_D: 1.35 Loss_G: 0.84
# Epoch 7 running time: 13.45
# [Epoch 8/50][Batch 0/300] Loss_D: 1.88 Loss_G: 0.81
# [Epoch 8/50][Batch 60/300] Loss_D: 1.27 Loss_G: 0.92
# [Epoch 8/50][Batch 120/300] Loss_D: 1.38 Loss_G: 1.31
# [Epoch 8/50][Batch 180/300] Loss_D: 1.37 Loss_G: 0.87
# [Epoch 8/50][Batch 240/300] Loss_D: 1.32 Loss_G: 0.86
# Epoch 8 running time: 14.54
# [Epoch 9/50][Batch 0/300] Loss_D: 1.31 Loss_G: 1.27
# [Epoch 9/50][Batch 60/300] Loss_D: 1.33 Loss_G: 0.83
# [Epoch 9/50][Batch 120/300] Loss_D: 1.23 Loss_G: 0.98
# [Epoch 9/50][Batch 180/300] Loss_D: 1.37 Loss_G: 0.81
# [Epoch 9/50][Batch 240/300] Loss_D: 1.38 Loss_G: 0.76
# Epoch 9 running time: 13.24
# [Epoch 10/50][Batch 0/300] Loss_D: 1.34 Loss_G: 0.88
# [Epoch 10/50][Batch 60/300] Loss_D: 1.31 Loss_G: 0.68
# [Epoch 10/50][Batch 120/300] Loss_D: 1.29 Loss_G: 0.84
# [Epoch 10/50][Batch 180/300] Loss_D: 1.31 Loss_G: 0.85
# [Epoch 10/50][Batch 240/300] Loss_D: 1.34 Loss_G: 0.82
# Epoch 10 running time: 12.83
# [Epoch 11/50][Batch 0/300] Loss_D: 1.77 Loss_G: 0.92
# [Epoch 11/50][Batch 60/300] Loss_D: 1.31 Loss_G: 0.78
# [Epoch 11/50][Batch 120/300] Loss_D: 1.30 Loss_G: 0.87
# [Epoch 11/50][Batch 180/300] Loss_D: 1.32 Loss_G: 0.77
# [Epoch 11/50][Batch 240/300] Loss_D: 1.30 Loss_G: 0.80
# Epoch 11 running time: 13.09
# [Epoch 12/50][Batch 0/300] Loss_D: 1.30 Loss_G: 0.73
# [Epoch 12/50][Batch 60/300] Loss_D: 1.31 Loss_G: 0.65
# [Epoch 12/50][Batch 120/300] Loss_D: 1.35 Loss_G: 0.73
# [Epoch 12/50][Batch 180/300] Loss_D: 1.36 Loss_G: 0.89
# [Epoch 12/50][Batch 240/300] Loss_D: 1.32 Loss_G: 0.84
# Epoch 12 running time: 14.43
# [Epoch 13/50][Batch 0/300] Loss_D: 1.25 Loss_G: 0.83
# [Epoch 13/50][Batch 60/300] Loss_D: 1.31 Loss_G: 0.94
# [Epoch 13/50][Batch 120/300] Loss_D: 1.25 Loss_G: 0.71
# [Epoch 13/50][Batch 180/300] Loss_D: 1.62 Loss_G: 0.81
# [Epoch 13/50][Batch 240/300] Loss_D: 1.29 Loss_G: 0.84
# Epoch 13 running time: 14.44
# [Epoch 14/50][Batch 0/300] Loss_D: 1.40 Loss_G: 0.72
# [Epoch 14/50][Batch 60/300] Loss_D: 1.34 Loss_G: 0.79
# [Epoch 14/50][Batch 120/300] Loss_D: 1.30 Loss_G: 0.72
# [Epoch 14/50][Batch 180/300] Loss_D: 1.36 Loss_G: 0.76
# [Epoch 14/50][Batch 240/300] Loss_D: 1.35 Loss_G: 0.89
# Epoch 14 running time: 13.04
# [Epoch 15/50][Batch 0/300] Loss_D: 1.34 Loss_G: 1.11
# [Epoch 15/50][Batch 60/300] Loss_D: 1.35 Loss_G: 0.84
# [Epoch 15/50][Batch 120/300] Loss_D: 1.32 Loss_G: 0.86
# [Epoch 15/50][Batch 180/300] Loss_D: 1.35 Loss_G: 0.80
# [Epoch 15/50][Batch 240/300] Loss_D: 1.32 Loss_G: 0.89
# Epoch 15 running time: 13.26
# [Epoch 16/50][Batch 0/300] Loss_D: 1.39 Loss_G: 0.75
# [Epoch 16/50][Batch 60/300] Loss_D: 1.31 Loss_G: 0.73
# [Epoch 16/50][Batch 120/300] Loss_D: 1.35 Loss_G: 0.68
# [Epoch 16/50][Batch 180/300] Loss_D: 1.35 Loss_G: 0.80
# [Epoch 16/50][Batch 240/300] Loss_D: 1.33 Loss_G: 0.85
# Epoch 16 running time: 12.93
# [Epoch 17/50][Batch 0/300] Loss_D: 1.30 Loss_G: 0.76
# [Epoch 17/50][Batch 60/300] Loss_D: 1.29 Loss_G: 1.02
# [Epoch 17/50][Batch 120/300] Loss_D: 1.43 Loss_G: 0.98
# [Epoch 17/50][Batch 180/300] Loss_D: 1.37 Loss_G: 0.74
# [Epoch 17/50][Batch 240/300] Loss_D: 1.37 Loss_G: 0.77
# Epoch 17 running time: 14.97
# [Epoch 18/50][Batch 0/300] Loss_D: 1.37 Loss_G: 0.78
# [Epoch 18/50][Batch 60/300] Loss_D: 1.36 Loss_G: 0.70
# [Epoch 18/50][Batch 120/300] Loss_D: 1.35 Loss_G: 0.86
# [Epoch 18/50][Batch 180/300] Loss_D: 1.35 Loss_G: 0.76
# [Epoch 18/50][Batch 240/300] Loss_D: 1.33 Loss_G: 0.74
# Epoch 18 running time: 12.67
# [Epoch 19/50][Batch 0/300] Loss_D: 1.34 Loss_G: 0.73
# [Epoch 19/50][Batch 60/300] Loss_D: 1.29 Loss_G: 0.71
# [Epoch 19/50][Batch 120/300] Loss_D: 1.35 Loss_G: 0.73
# [Epoch 19/50][Batch 180/300] Loss_D: 1.31 Loss_G: 0.85
# [Epoch 19/50][Batch 240/300] Loss_D: 1.36 Loss_G: 0.68
# Epoch 19 running time: 13.49
# [Epoch 20/50][Batch 0/300] Loss_D: 1.31 Loss_G: 0.78
# [Epoch 20/50][Batch 60/300] Loss_D: 1.34 Loss_G: 0.79
# [Epoch 20/50][Batch 120/300] Loss_D: 1.39 Loss_G: 0.85
# [Epoch 20/50][Batch 180/300] Loss_D: 1.34 Loss_G: 0.83
# [Epoch 20/50][Batch 240/300] Loss_D: 1.39 Loss_G: 0.82
# Epoch 20 running time: 13.60
# [Epoch 21/50][Batch 0/300] Loss_D: 1.32 Loss_G: 1.09
# [Epoch 21/50][Batch 60/300] Loss_D: 1.37 Loss_G: 0.87
# [Epoch 21/50][Batch 120/300] Loss_D: 1.35 Loss_G: 0.66
# [Epoch 21/50][Batch 180/300] Loss_D: 1.44 Loss_G: 0.97
# [Epoch 21/50][Batch 240/300] Loss_D: 1.34 Loss_G: 0.88
# Epoch 21 running time: 15.13
# [Epoch 22/50][Batch 0/300] Loss_D: 1.58 Loss_G: 0.91
# [Epoch 22/50][Batch 60/300] Loss_D: 1.32 Loss_G: 0.74
# [Epoch 22/50][Batch 120/300] Loss_D: 1.38 Loss_G: 0.93
# [Epoch 22/50][Batch 180/300] Loss_D: 1.31 Loss_G: 0.85
# [Epoch 22/50][Batch 240/300] Loss_D: 1.37 Loss_G: 0.70
# Epoch 22 running time: 13.49
# [Epoch 23/50][Batch 0/300] Loss_D: 1.35 Loss_G: 0.80
# [Epoch 23/50][Batch 60/300] Loss_D: 1.36 Loss_G: 0.91
# [Epoch 23/50][Batch 120/300] Loss_D: 1.35 Loss_G: 0.66
# [Epoch 23/50][Batch 180/300] Loss_D: 1.34 Loss_G: 0.73
# [Epoch 23/50][Batch 240/300] Loss_D: 1.38 Loss_G: 0.80
# Epoch 23 running time: 13.24
# [Epoch 24/50][Batch 0/300] Loss_D: 1.39 Loss_G: 0.78
# [Epoch 24/50][Batch 60/300] Loss_D: 1.29 Loss_G: 0.70
# [Epoch 24/50][Batch 120/300] Loss_D: 1.32 Loss_G: 0.73
# [Epoch 24/50][Batch 180/300] Loss_D: 1.31 Loss_G: 0.85
# [Epoch 24/50][Batch 240/300] Loss_D: 1.29 Loss_G: 0.76
# Epoch 24 running time: 13.29
# [Epoch 25/50][Batch 0/300] Loss_D: 1.34 Loss_G: 0.78
# [Epoch 25/50][Batch 60/300] Loss_D: 1.31 Loss_G: 0.83
# [Epoch 25/50][Batch 120/300] Loss_D: 1.28 Loss_G: 0.89
# [Epoch 25/50][Batch 180/300] Loss_D: 1.37 Loss_G: 0.87
# [Epoch 25/50][Batch 240/300] Loss_D: 1.29 Loss_G: 0.83
# Epoch 25 running time: 13.76
# [Epoch 26/50][Batch 0/300] Loss_D: 1.30 Loss_G: 0.70
# [Epoch 26/50][Batch 60/300] Loss_D: 1.29 Loss_G: 0.84
# [Epoch 26/50][Batch 120/300] Loss_D: 1.22 Loss_G: 0.84
# [Epoch 26/50][Batch 180/300] Loss_D: 1.32 Loss_G: 0.86
# [Epoch 26/50][Batch 240/300] Loss_D: 1.32 Loss_G: 0.70
# Epoch 26 running time: 15.30
# [Epoch 27/50][Batch 0/300] Loss_D: 1.33 Loss_G: 0.85
# [Epoch 27/50][Batch 60/300] Loss_D: 1.33 Loss_G: 0.79
# [Epoch 27/50][Batch 120/300] Loss_D: 1.33 Loss_G: 0.84
# [Epoch 27/50][Batch 180/300] Loss_D: 1.36 Loss_G: 0.99
# [Epoch 27/50][Batch 240/300] Loss_D: 1.28 Loss_G: 0.82
# Epoch 27 running time: 12.85
# [Epoch 28/50][Batch 0/300] Loss_D: 1.29 Loss_G: 0.83
# [Epoch 28/50][Batch 60/300] Loss_D: 1.41 Loss_G: 0.84
# [Epoch 28/50][Batch 120/300] Loss_D: 1.32 Loss_G: 0.94
# [Epoch 28/50][Batch 180/300] Loss_D: 1.30 Loss_G: 0.80
# [Epoch 28/50][Batch 240/300] Loss_D: 1.32 Loss_G: 0.77
# Epoch 28 running time: 13.13
# [Epoch 29/50][Batch 0/300] Loss_D: 1.33 Loss_G: 0.71
# [Epoch 29/50][Batch 60/300] Loss_D: 1.35 Loss_G: 0.86
# [Epoch 29/50][Batch 120/300] Loss_D: 1.26 Loss_G: 0.83
# [Epoch 29/50][Batch 180/300] Loss_D: 1.39 Loss_G: 0.75
# [Epoch 29/50][Batch 240/300] Loss_D: 1.25 Loss_G: 0.72
# Epoch 29 running time: 13.01
# [Epoch 30/50][Batch 0/300] Loss_D: 1.31 Loss_G: 0.79
# [Epoch 30/50][Batch 60/300] Loss_D: 1.35 Loss_G: 0.84
# [Epoch 30/50][Batch 120/300] Loss_D: 1.40 Loss_G: 0.95
# [Epoch 30/50][Batch 180/300] Loss_D: 1.36 Loss_G: 0.91
# [Epoch 30/50][Batch 240/300] Loss_D: 1.30 Loss_G: 0.83
# Epoch 30 running time: 14.94
# [Epoch 31/50][Batch 0/300] Loss_D: 1.35 Loss_G: 0.83
# [Epoch 31/50][Batch 60/300] Loss_D: 1.26 Loss_G: 0.80
# [Epoch 31/50][Batch 120/300] Loss_D: 1.31 Loss_G: 0.78
# [Epoch 31/50][Batch 180/300] Loss_D: 1.71 Loss_G: 0.99
# [Epoch 31/50][Batch 240/300] Loss_D: 1.33 Loss_G: 0.77
# Epoch 31 running time: 13.67
# [Epoch 32/50][Batch 0/300] Loss_D: 1.30 Loss_G: 0.82
# [Epoch 32/50][Batch 60/300] Loss_D: 1.37 Loss_G: 0.72
# [Epoch 32/50][Batch 120/300] Loss_D: 1.30 Loss_G: 0.69
# [Epoch 32/50][Batch 180/300] Loss_D: 1.25 Loss_G: 0.92
# [Epoch 32/50][Batch 240/300] Loss_D: 1.34 Loss_G: 1.10
# Epoch 32 running time: 12.84
# [Epoch 33/50][Batch 0/300] Loss_D: 1.32 Loss_G: 0.79
# [Epoch 33/50][Batch 60/300] Loss_D: 1.32 Loss_G: 0.91
# [Epoch 33/50][Batch 120/300] Loss_D: 1.36 Loss_G: 0.84
# [Epoch 33/50][Batch 180/300] Loss_D: 1.30 Loss_G: 0.78
# [Epoch 33/50][Batch 240/300] Loss_D: 1.26 Loss_G: 0.79
# Epoch 33 running time: 13.05
# [Epoch 34/50][Batch 0/300] Loss_D: 1.32 Loss_G: 0.80
# [Epoch 34/50][Batch 60/300] Loss_D: 1.32 Loss_G: 0.81
# [Epoch 34/50][Batch 120/300] Loss_D: 1.39 Loss_G: 1.13
# [Epoch 34/50][Batch 180/300] Loss_D: 1.35 Loss_G: 0.86
# [Epoch 34/50][Batch 240/300] Loss_D: 1.30 Loss_G: 0.85
# Epoch 34 running time: 14.46
# [Epoch 35/50][Batch 0/300] Loss_D: 1.35 Loss_G: 0.79
# [Epoch 35/50][Batch 60/300] Loss_D: 1.31 Loss_G: 0.83
# [Epoch 35/50][Batch 120/300] Loss_D: 1.31 Loss_G: 0.83
# [Epoch 35/50][Batch 180/300] Loss_D: 1.36 Loss_G: 0.76
# [Epoch 35/50][Batch 240/300] Loss_D: 1.33 Loss_G: 0.86
# Epoch 35 running time: 11.83
# [Epoch 36/50][Batch 0/300] Loss_D: 1.33 Loss_G: 0.81
# [Epoch 36/50][Batch 60/300] Loss_D: 1.32 Loss_G: 1.21
# [Epoch 36/50][Batch 120/300] Loss_D: 1.39 Loss_G: 0.86
# [Epoch 36/50][Batch 180/300] Loss_D: 1.30 Loss_G: 0.86
# [Epoch 36/50][Batch 240/300] Loss_D: 1.36 Loss_G: 0.92
# Epoch 36 running time: 13.11
# [Epoch 37/50][Batch 0/300] Loss_D: 1.38 Loss_G: 0.80
# [Epoch 37/50][Batch 60/300] Loss_D: 1.27 Loss_G: 0.95
# [Epoch 37/50][Batch 120/300] Loss_D: 1.28 Loss_G: 0.80
# [Epoch 37/50][Batch 180/300] Loss_D: 1.28 Loss_G: 0.86
# [Epoch 37/50][Batch 240/300] Loss_D: 1.38 Loss_G: 0.46
# Epoch 37 running time: 12.74
# [Epoch 38/50][Batch 0/300] Loss_D: 1.40 Loss_G: 0.70
# [Epoch 38/50][Batch 60/300] Loss_D: 1.38 Loss_G: 1.31
# [Epoch 38/50][Batch 120/300] Loss_D: 1.36 Loss_G: 0.88
# [Epoch 38/50][Batch 180/300] Loss_D: 1.33 Loss_G: 0.81
# [Epoch 38/50][Batch 240/300] Loss_D: 1.39 Loss_G: 0.92
# Epoch 38 running time: 14.77
# [Epoch 39/50][Batch 0/300] Loss_D: 1.30 Loss_G: 0.77
# [Epoch 39/50][Batch 60/300] Loss_D: 1.30 Loss_G: 0.86
# [Epoch 39/50][Batch 120/300] Loss_D: 1.35 Loss_G: 0.79
# [Epoch 39/50][Batch 180/300] Loss_D: 1.32 Loss_G: 0.98
# [Epoch 39/50][Batch 240/300] Loss_D: 1.32 Loss_G: 0.92
# Epoch 39 running time: 13.52
# [Epoch 40/50][Batch 0/300] Loss_D: 1.46 Loss_G: 0.59
# [Epoch 40/50][Batch 60/300] Loss_D: 1.37 Loss_G: 0.82
# [Epoch 40/50][Batch 120/300] Loss_D: 1.31 Loss_G: 0.83
# [Epoch 40/50][Batch 180/300] Loss_D: 1.30 Loss_G: 0.70
# [Epoch 40/50][Batch 240/300] Loss_D: 1.44 Loss_G: 0.46
# Epoch 40 running time: 13.14
# [Epoch 41/50][Batch 0/300] Loss_D: 1.32 Loss_G: 0.78
# [Epoch 41/50][Batch 60/300] Loss_D: 1.29 Loss_G: 0.88
# [Epoch 41/50][Batch 120/300] Loss_D: 1.33 Loss_G: 0.98
# [Epoch 41/50][Batch 180/300] Loss_D: 1.35 Loss_G: 0.85
# [Epoch 41/50][Batch 240/300] Loss_D: 1.30 Loss_G: 0.73
# Epoch 41 running time: 12.50
# [Epoch 42/50][Batch 0/300] Loss_D: 1.31 Loss_G: 0.80
# [Epoch 42/50][Batch 60/300] Loss_D: 1.33 Loss_G: 0.90
# [Epoch 42/50][Batch 120/300] Loss_D: 1.31 Loss_G: 0.83
# [Epoch 42/50][Batch 180/300] Loss_D: 1.34 Loss_G: 0.62
# [Epoch 42/50][Batch 240/300] Loss_D: 1.30 Loss_G: 0.81
# Epoch 42 running time: 14.20
# [Epoch 43/50][Batch 0/300] Loss_D: 1.33 Loss_G: 0.81
# [Epoch 43/50][Batch 60/300] Loss_D: 1.34 Loss_G: 1.16
# [Epoch 43/50][Batch 120/300] Loss_D: 1.29 Loss_G: 0.98
# [Epoch 43/50][Batch 180/300] Loss_D: 1.31 Loss_G: 0.82
# [Epoch 43/50][Batch 240/300] Loss_D: 1.37 Loss_G: 0.77
# Epoch 43 running time: 12.09
# [Epoch 44/50][Batch 0/300] Loss_D: 1.40 Loss_G: 0.83
# [Epoch 44/50][Batch 60/300] Loss_D: 1.29 Loss_G: 0.76
# [Epoch 44/50][Batch 120/300] Loss_D: 1.30 Loss_G: 0.74
# [Epoch 44/50][Batch 180/300] Loss_D: 1.33 Loss_G: 0.83
# [Epoch 44/50][Batch 240/300] Loss_D: 1.37 Loss_G: 1.04
# Epoch 44 running time: 12.71
# [Epoch 45/50][Batch 0/300] Loss_D: 1.39 Loss_G: 0.74
# [Epoch 45/50][Batch 60/300] Loss_D: 1.42 Loss_G: 1.64
# [Epoch 45/50][Batch 120/300] Loss_D: 1.31 Loss_G: 0.89
# [Epoch 45/50][Batch 180/300] Loss_D: 1.39 Loss_G: 1.02
# [Epoch 45/50][Batch 240/300] Loss_D: 1.33 Loss_G: 0.73
# Epoch 45 running time: 12.90
# [Epoch 46/50][Batch 0/300] Loss_D: 1.39 Loss_G: 0.64
# [Epoch 46/50][Batch 60/300] Loss_D: 1.34 Loss_G: 0.90
# [Epoch 46/50][Batch 120/300] Loss_D: 1.33 Loss_G: 0.84
# [Epoch 46/50][Batch 180/300] Loss_D: 1.27 Loss_G: 0.98
# [Epoch 46/50][Batch 240/300] Loss_D: 1.33 Loss_G: 0.72
# Epoch 46 running time: 14.50
# [Epoch 47/50][Batch 0/300] Loss_D: 1.32 Loss_G: 0.88
# [Epoch 47/50][Batch 60/300] Loss_D: 1.31 Loss_G: 0.81
# [Epoch 47/50][Batch 120/300] Loss_D: 1.36 Loss_G: 0.64
# [Epoch 47/50][Batch 180/300] Loss_D: 1.41 Loss_G: 0.75
# [Epoch 47/50][Batch 240/300] Loss_D: 1.35 Loss_G: 0.83
# Epoch 47 running time: 12.79
# [Epoch 48/50][Batch 0/300] Loss_D: 1.32 Loss_G: 0.80
# [Epoch 48/50][Batch 60/300] Loss_D: 1.56 Loss_G: 0.90
# [Epoch 48/50][Batch 120/300] Loss_D: 1.29 Loss_G: 0.79
# [Epoch 48/50][Batch 180/300] Loss_D: 1.33 Loss_G: 1.12
# [Epoch 48/50][Batch 240/300] Loss_D: 1.34 Loss_G: 0.82
# Epoch 48 running time: 12.85
# [Epoch 49/50][Batch 0/300] Loss_D: 1.29 Loss_G: 0.73
# [Epoch 49/50][Batch 60/300] Loss_D: 1.29 Loss_G: 0.99
# [Epoch 49/50][Batch 120/300] Loss_D: 1.32 Loss_G: 0.76
# [Epoch 49/50][Batch 180/300] Loss_D: 1.31 Loss_G: 0.81
# [Epoch 49/50][Batch 240/300] Loss_D: 1.29 Loss_G: 0.85
# Epoch 49 running time: 13.43
# Total running time: 672.80s

# %%
plt.figure(figsize=(8,3))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(trainer.g_losses,label="G")
plt.plot(trainer.d_losses,label="D")

plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.savefig(os.path.join(output_root, data_name, 'g_d_loss.png'))
plt.show()

# %%
gif_generator(image_dir=os.path.join(output_root, data_name), 
              name_pattern=r'fake_samples_epoch_[\d]+|.png')
