# %% [markdown]
# ## Libraries

# %%
import sys
sys.path.append('./venv/lib/python3.6/site-packages')

# %%
import os
import time
import random

import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image

# %%
import torch
from torch import nn
from torch import optim
from torchvision import transforms as vtransforms
from torchvision import utils as vutils
from torchvision import datasets

# %%
from gans.utils.data import CartoonSet
from gans.utils.layers import *
from gans.utils.functions import *
from gans.models import *
from gans.trainer import *

# %% [markdown]
# ## Random seed

# %%
# Set random seem for reproducibility
# manualSeed = 999
manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)
# Out:
# Random Seed:  2152

# %% [markdown]
# ## Inputs

# %%
# Dataset
data_root = './datasets'
# data_name = 'CartoonSet'
data_name = 'FashionMNIST'
# data_name = 'MNIST'

batch_size = 200
sample_size = 50
nrow = 5

num_epochs = 50

num_workers = 8


# Output dir
output_root = './output/CGAN'
# overwrite real sample output
overwrite_real = False

noize_dim = 100

# Optimization parameters
lr = 0.001
beta1 = 0.5

# %% [markdown]
# ## Device

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print('using device: ', device)
# Out:
# using device:  cuda:0

# %% [markdown]
# ## Dataset

# %%
img_size = 28
in_channels = 1

if data_name == 'CartoonSet':
    img_size = 75
    dataset = CartoonSet(root=os.path.join(data_root, data_name), 
                         transform=vtransforms.Compose([
                             vtransforms.CenterCrop(size=400),
                             vtransforms.Resize(size=img_size), 
                             vtransforms.ToTensor(),
                             vtransforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5)),
                         ]))
    
elif data_name == 'MNIST':
    dataset = datasets.MNIST(root=os.path.join(data_root, data_name), 
                             download=True,
                             transform=vtransforms.Compose([
                                 vtransforms.ToTensor(),
                                 vtransforms.Normalize((0.5,), (0.5,)),
                         ]))
elif data_name == 'FashionMNIST':
    dataset = datasets.FashionMNIST(root=os.path.join(data_root, data_name), 
                                    download=True,
                                    transform=vtransforms.Compose([
                                        vtransforms.ToTensor(),
                                        vtransforms.Normalize((0.5,), (0.5,)),
                                    ]))
    
dtype = dataset[0][0].dtype
img_shape = dataset[0][0].shape

# %% [markdown]
# ## Dataloader

# %%
dataloader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         shuffle=True, 
                                         num_workers=num_workers)

# %%
if not os.path.exists(os.path.join(output_root, data_name)):
    os.makedirs(os.path.join(output_root, data_name))

real_sample_path = os.path.join(output_root, data_name, 'real_samples.png')


real_batch = next(iter(dataloader))

vutils.save_image(real_batch[0], real_sample_path, 
                  normalize=True, range=(0,1), nrow=nrow)
Image(real_sample_path)

# %% [markdown]
# ## Model

# %%
C, H, W = img_shape
features = C * H * W

# %%
layersG = [
    *linearBlock(noize_dim+10, 128, normalize=False, activation='ReLU'),
    *linearBlock(128, 256, activation='ReLU'),
    *linearBlock(256, 512, activation='ReLU'),
    *linearBlock(512, 1024, activation='ReLU'),
    *linearBlock(1024, features, normalize=False, activation='Tanh'),
]

netG = ConditionalGenerator(layers=layersG, img_shape=img_shape)
print(netG)
# Out:
# ConditionalGenerator(
#   (encoder): OneHotEncoder()
#   (model): Sequential(
#     (0): Linear(in_features=110, out_features=128, bias=True)
#     (1): ReLU(inplace)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU(inplace)
#     (8): Linear(in_features=512, out_features=1024, bias=True)
#     (9): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace)
#     (11): Linear(in_features=1024, out_features=784, bias=True)
#     (12): Tanh()
#     (13): Unflatten2d(img_shape=(1, 28, 28))
#   )
# )

# %%
layersD = [
    *linearBlock(features+10, 1024, normalize=False, activation='LeakyReLU'),
    *linearBlock(1024, 512, normalize=False, activation='LeakyReLU'),
    *linearBlock(512, 256, normalize=False, activation='LeakyReLU'),
    *linearBlock(256, 128, normalize=False, activation='LeakyReLU'),
    *linearBlock(128, 1, normalize=False, activation='Sigmoid'),
]

netD = ConditionalDiscriminator(layers=layersD)
print(netD)
# Out:
# ConditionalDiscriminator(
#   (flatten): Flatten()
#   (encoder): OneHotEncoder()
#   (model): Sequential(
#     (0): Linear(in_features=794, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace)
#     (2): Linear(in_features=1024, out_features=512, bias=True)
#     (3): LeakyReLU(negative_slope=0.2, inplace)
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace)
#     (6): Linear(in_features=256, out_features=128, bias=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace)
#     (8): Linear(in_features=128, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )

# %% [markdown]
# ## Training

# %%
y_fixed = torch.tensor([i//nrow for i in range(sample_size)], device=device)

# %%
trainer = CGANTrainer(generator=netG, discriminator=netD,
                     optimizer=optim.Adam, loss=nn.BCELoss(), y_fixed=y_fixed,
                     device=device, multi_gpu=False, output_path=os.path.join(output_root, data_name),
                     batch_size=batch_size, num_epochs=num_epochs, sample_size=sample_size)

# %%
trainer.train(dataloader=dataloader, nrow=nrow)
# Out:
# /home/shu/.local/lib/python3.6/site-packages/torch/nn/functional.py:2016: UserWarning: Using a target size (torch.Size([200])) that is different to the input size (torch.Size([200, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# [Epoch 0/50][Batch 0/300] Loss_D: 1.39 Loss_G: 0.71
# [Epoch 0/50][Batch 60/300] Loss_D: 0.88 Loss_G: 1.09
# [Epoch 0/50][Batch 120/300] Loss_D: 1.49 Loss_G: 0.50
# [Epoch 0/50][Batch 180/300] Loss_D: 1.17 Loss_G: 0.72
# [Epoch 0/50][Batch 240/300] Loss_D: 0.89 Loss_G: 3.36
# Epoch 0 running time: 2.92
# [Epoch 1/50][Batch 0/300] Loss_D: 0.95 Loss_G: 1.56
# [Epoch 1/50][Batch 60/300] Loss_D: 0.98 Loss_G: 1.84
# [Epoch 1/50][Batch 120/300] Loss_D: 1.18 Loss_G: 1.74
# [Epoch 1/50][Batch 180/300] Loss_D: 1.07 Loss_G: 1.47
# [Epoch 1/50][Batch 240/300] Loss_D: 1.02 Loss_G: 1.25
# Epoch 1 running time: 2.80
# [Epoch 2/50][Batch 0/300] Loss_D: 1.55 Loss_G: 1.00
# [Epoch 2/50][Batch 60/300] Loss_D: 1.15 Loss_G: 2.34
# [Epoch 2/50][Batch 120/300] Loss_D: 1.27 Loss_G: 1.22
# [Epoch 2/50][Batch 180/300] Loss_D: 1.20 Loss_G: 0.92
# [Epoch 2/50][Batch 240/300] Loss_D: 1.17 Loss_G: 1.18
# Epoch 2 running time: 3.12
# [Epoch 3/50][Batch 0/300] Loss_D: 1.22 Loss_G: 1.44
# [Epoch 3/50][Batch 60/300] Loss_D: 1.25 Loss_G: 1.30
# [Epoch 3/50][Batch 120/300] Loss_D: 1.19 Loss_G: 1.11
# [Epoch 3/50][Batch 180/300] Loss_D: 1.31 Loss_G: 1.00
# [Epoch 3/50][Batch 240/300] Loss_D: 1.26 Loss_G: 0.88
# Epoch 3 running time: 2.83
# [Epoch 4/50][Batch 0/300] Loss_D: 1.33 Loss_G: 0.76
# [Epoch 4/50][Batch 60/300] Loss_D: 1.65 Loss_G: 0.67
# [Epoch 4/50][Batch 120/300] Loss_D: 1.33 Loss_G: 0.87
# [Epoch 4/50][Batch 180/300] Loss_D: 1.15 Loss_G: 0.78
# [Epoch 4/50][Batch 240/300] Loss_D: 1.33 Loss_G: 0.94
# Epoch 4 running time: 2.95
# [Epoch 5/50][Batch 0/300] Loss_D: 1.31 Loss_G: 1.09
# [Epoch 5/50][Batch 60/300] Loss_D: 1.26 Loss_G: 0.93
# [Epoch 5/50][Batch 120/300] Loss_D: 1.40 Loss_G: 0.65
# [Epoch 5/50][Batch 180/300] Loss_D: 1.30 Loss_G: 0.86
# [Epoch 5/50][Batch 240/300] Loss_D: 1.38 Loss_G: 1.38
# Epoch 5 running time: 2.73
# [Epoch 6/50][Batch 0/300] Loss_D: 1.33 Loss_G: 1.09
# [Epoch 6/50][Batch 60/300] Loss_D: 1.23 Loss_G: 0.91
# [Epoch 6/50][Batch 120/300] Loss_D: 1.33 Loss_G: 0.93
# [Epoch 6/50][Batch 180/300] Loss_D: 1.26 Loss_G: 1.04
# [Epoch 6/50][Batch 240/300] Loss_D: 1.31 Loss_G: 1.00
# Epoch 6 running time: 3.02
# [Epoch 7/50][Batch 0/300] Loss_D: 1.18 Loss_G: 0.95
# [Epoch 7/50][Batch 60/300] Loss_D: 1.33 Loss_G: 0.76
# [Epoch 7/50][Batch 120/300] Loss_D: 1.25 Loss_G: 1.22
# [Epoch 7/50][Batch 180/300] Loss_D: 1.27 Loss_G: 1.24
# [Epoch 7/50][Batch 240/300] Loss_D: 1.43 Loss_G: 0.44
# Epoch 7 running time: 2.80
# [Epoch 8/50][Batch 0/300] Loss_D: 1.31 Loss_G: 0.74
# [Epoch 8/50][Batch 60/300] Loss_D: 1.31 Loss_G: 0.96
# [Epoch 8/50][Batch 120/300] Loss_D: 1.35 Loss_G: 0.77
# [Epoch 8/50][Batch 180/300] Loss_D: 1.28 Loss_G: 0.83
# [Epoch 8/50][Batch 240/300] Loss_D: 1.27 Loss_G: 0.77
# Epoch 8 running time: 3.01
# [Epoch 9/50][Batch 0/300] Loss_D: 1.35 Loss_G: 0.85
# [Epoch 9/50][Batch 60/300] Loss_D: 1.33 Loss_G: 0.84
# [Epoch 9/50][Batch 120/300] Loss_D: 1.42 Loss_G: 1.67
# [Epoch 9/50][Batch 180/300] Loss_D: 1.38 Loss_G: 0.94
# [Epoch 9/50][Batch 240/300] Loss_D: 1.38 Loss_G: 1.17
# Epoch 9 running time: 2.94
# [Epoch 10/50][Batch 0/300] Loss_D: 1.34 Loss_G: 1.19
# [Epoch 10/50][Batch 60/300] Loss_D: 1.34 Loss_G: 0.90
# [Epoch 10/50][Batch 120/300] Loss_D: 1.22 Loss_G: 1.03
# [Epoch 10/50][Batch 180/300] Loss_D: 1.32 Loss_G: 0.72
# [Epoch 10/50][Batch 240/300] Loss_D: 1.35 Loss_G: 0.69
# Epoch 10 running time: 2.98
# [Epoch 11/50][Batch 0/300] Loss_D: 1.27 Loss_G: 0.88
# [Epoch 11/50][Batch 60/300] Loss_D: 1.27 Loss_G: 0.72
# [Epoch 11/50][Batch 120/300] Loss_D: 1.30 Loss_G: 0.82
# [Epoch 11/50][Batch 180/300] Loss_D: 1.31 Loss_G: 0.88
# [Epoch 11/50][Batch 240/300] Loss_D: 1.31 Loss_G: 0.92
# Epoch 11 running time: 2.94
# [Epoch 12/50][Batch 0/300] Loss_D: 1.39 Loss_G: 0.70
# [Epoch 12/50][Batch 60/300] Loss_D: 1.30 Loss_G: 1.01
# [Epoch 12/50][Batch 120/300] Loss_D: 1.37 Loss_G: 0.95
# [Epoch 12/50][Batch 180/300] Loss_D: 1.32 Loss_G: 0.87
# [Epoch 12/50][Batch 240/300] Loss_D: 1.32 Loss_G: 0.92
# Epoch 12 running time: 3.01
# [Epoch 13/50][Batch 0/300] Loss_D: 1.42 Loss_G: 0.76
# [Epoch 13/50][Batch 60/300] Loss_D: 1.32 Loss_G: 0.86
# [Epoch 13/50][Batch 120/300] Loss_D: 1.34 Loss_G: 0.82
# [Epoch 13/50][Batch 180/300] Loss_D: 1.30 Loss_G: 0.83
# [Epoch 13/50][Batch 240/300] Loss_D: 1.30 Loss_G: 0.79
# Epoch 13 running time: 2.82
# [Epoch 14/50][Batch 0/300] Loss_D: 1.30 Loss_G: 0.74
# [Epoch 14/50][Batch 60/300] Loss_D: 1.30 Loss_G: 0.95
# [Epoch 14/50][Batch 120/300] Loss_D: 1.40 Loss_G: 0.92
# [Epoch 14/50][Batch 180/300] Loss_D: 1.32 Loss_G: 0.63
# [Epoch 14/50][Batch 240/300] Loss_D: 1.35 Loss_G: 0.70
# Epoch 14 running time: 3.07
# [Epoch 15/50][Batch 0/300] Loss_D: 1.27 Loss_G: 0.84
# [Epoch 15/50][Batch 60/300] Loss_D: 1.36 Loss_G: 0.86
# [Epoch 15/50][Batch 120/300] Loss_D: 1.31 Loss_G: 0.86
# [Epoch 15/50][Batch 180/300] Loss_D: 1.35 Loss_G: 0.79
# [Epoch 15/50][Batch 240/300] Loss_D: 1.33 Loss_G: 1.05
# Epoch 15 running time: 2.80
# [Epoch 16/50][Batch 0/300] Loss_D: 1.36 Loss_G: 0.79
# [Epoch 16/50][Batch 60/300] Loss_D: 1.37 Loss_G: 0.89
# [Epoch 16/50][Batch 120/300] Loss_D: 1.42 Loss_G: 1.25
# [Epoch 16/50][Batch 180/300] Loss_D: 1.37 Loss_G: 1.11
# [Epoch 16/50][Batch 240/300] Loss_D: 1.34 Loss_G: 0.79
# Epoch 16 running time: 2.95
# [Epoch 17/50][Batch 0/300] Loss_D: 1.29 Loss_G: 0.76
# [Epoch 17/50][Batch 60/300] Loss_D: 1.33 Loss_G: 0.86
# [Epoch 17/50][Batch 120/300] Loss_D: 1.35 Loss_G: 0.84
# [Epoch 17/50][Batch 180/300] Loss_D: 1.37 Loss_G: 0.92
# [Epoch 17/50][Batch 240/300] Loss_D: 1.30 Loss_G: 0.81
# Epoch 17 running time: 2.84
# [Epoch 18/50][Batch 0/300] Loss_D: 1.38 Loss_G: 0.74
# [Epoch 18/50][Batch 60/300] Loss_D: 1.39 Loss_G: 0.81
# [Epoch 18/50][Batch 120/300] Loss_D: 1.33 Loss_G: 0.77
# [Epoch 18/50][Batch 180/300] Loss_D: 1.37 Loss_G: 0.75
# [Epoch 18/50][Batch 240/300] Loss_D: 1.44 Loss_G: 0.88
# Epoch 18 running time: 2.95
# [Epoch 19/50][Batch 0/300] Loss_D: 1.54 Loss_G: 0.89
# [Epoch 19/50][Batch 60/300] Loss_D: 1.44 Loss_G: 0.78
# [Epoch 19/50][Batch 120/300] Loss_D: 1.31 Loss_G: 0.74
# [Epoch 19/50][Batch 180/300] Loss_D: 1.31 Loss_G: 0.94
# [Epoch 19/50][Batch 240/300] Loss_D: 1.28 Loss_G: 1.18
# Epoch 19 running time: 2.80
# [Epoch 20/50][Batch 0/300] Loss_D: 1.37 Loss_G: 0.56
# [Epoch 20/50][Batch 60/300] Loss_D: 1.34 Loss_G: 0.79
# [Epoch 20/50][Batch 120/300] Loss_D: 1.34 Loss_G: 0.76
# [Epoch 20/50][Batch 180/300] Loss_D: 1.29 Loss_G: 0.75
# [Epoch 20/50][Batch 240/300] Loss_D: 1.35 Loss_G: 0.79
# Epoch 20 running time: 2.91
# [Epoch 21/50][Batch 0/300] Loss_D: 1.45 Loss_G: 0.89
# [Epoch 21/50][Batch 60/300] Loss_D: 1.34 Loss_G: 0.75
# [Epoch 21/50][Batch 120/300] Loss_D: 1.33 Loss_G: 0.76
# [Epoch 21/50][Batch 180/300] Loss_D: 1.34 Loss_G: 0.63
# [Epoch 21/50][Batch 240/300] Loss_D: 1.37 Loss_G: 0.70
# Epoch 21 running time: 2.81
# [Epoch 22/50][Batch 0/300] Loss_D: 1.39 Loss_G: 0.80
# [Epoch 22/50][Batch 60/300] Loss_D: 1.30 Loss_G: 0.88
# [Epoch 22/50][Batch 120/300] Loss_D: 1.32 Loss_G: 0.75
# [Epoch 22/50][Batch 180/300] Loss_D: 1.37 Loss_G: 0.78
# [Epoch 22/50][Batch 240/300] Loss_D: 1.32 Loss_G: 0.75
# Epoch 22 running time: 2.92
# [Epoch 23/50][Batch 0/300] Loss_D: 1.49 Loss_G: 0.92
# [Epoch 23/50][Batch 60/300] Loss_D: 1.33 Loss_G: 0.83
# [Epoch 23/50][Batch 120/300] Loss_D: 1.35 Loss_G: 0.77
# [Epoch 23/50][Batch 180/300] Loss_D: 1.68 Loss_G: 0.84
# [Epoch 23/50][Batch 240/300] Loss_D: 1.32 Loss_G: 0.75
# Epoch 23 running time: 2.75
# [Epoch 24/50][Batch 0/300] Loss_D: 1.33 Loss_G: 0.89
# [Epoch 24/50][Batch 60/300] Loss_D: 1.37 Loss_G: 0.73
# [Epoch 24/50][Batch 120/300] Loss_D: 1.34 Loss_G: 0.77
# [Epoch 24/50][Batch 180/300] Loss_D: 1.32 Loss_G: 0.79
# [Epoch 24/50][Batch 240/300] Loss_D: 1.33 Loss_G: 0.75
# Epoch 24 running time: 2.74
# [Epoch 25/50][Batch 0/300] Loss_D: 1.38 Loss_G: 0.84
# [Epoch 25/50][Batch 60/300] Loss_D: 1.44 Loss_G: 0.74
# [Epoch 25/50][Batch 120/300] Loss_D: 1.32 Loss_G: 0.74
# [Epoch 25/50][Batch 180/300] Loss_D: 1.36 Loss_G: 0.76
# [Epoch 25/50][Batch 240/300] Loss_D: 1.36 Loss_G: 0.78
# Epoch 25 running time: 2.86
# [Epoch 26/50][Batch 0/300] Loss_D: 1.40 Loss_G: 0.68
# [Epoch 26/50][Batch 60/300] Loss_D: 1.26 Loss_G: 0.75
# [Epoch 26/50][Batch 120/300] Loss_D: 1.35 Loss_G: 0.76
# [Epoch 26/50][Batch 180/300] Loss_D: 1.36 Loss_G: 0.70
# [Epoch 26/50][Batch 240/300] Loss_D: 1.34 Loss_G: 0.76
# Epoch 26 running time: 3.01
# [Epoch 27/50][Batch 0/300] Loss_D: 1.38 Loss_G: 0.69
# [Epoch 27/50][Batch 60/300] Loss_D: 1.33 Loss_G: 0.77
# [Epoch 27/50][Batch 120/300] Loss_D: 1.29 Loss_G: 0.82
# [Epoch 27/50][Batch 180/300] Loss_D: 1.35 Loss_G: 0.76
# [Epoch 27/50][Batch 240/300] Loss_D: 1.37 Loss_G: 0.72
# Epoch 27 running time: 2.81
# [Epoch 28/50][Batch 0/300] Loss_D: 1.32 Loss_G: 0.73
# [Epoch 28/50][Batch 60/300] Loss_D: 1.27 Loss_G: 0.94
# [Epoch 28/50][Batch 120/300] Loss_D: 1.40 Loss_G: 0.79
# [Epoch 28/50][Batch 180/300] Loss_D: 1.36 Loss_G: 0.71
# [Epoch 28/50][Batch 240/300] Loss_D: 1.40 Loss_G: 0.83
# Epoch 28 running time: 2.94
# [Epoch 29/50][Batch 0/300] Loss_D: 1.34 Loss_G: 0.90
# [Epoch 29/50][Batch 60/300] Loss_D: 1.32 Loss_G: 0.79
# [Epoch 29/50][Batch 120/300] Loss_D: 1.32 Loss_G: 0.77
# [Epoch 29/50][Batch 180/300] Loss_D: 1.38 Loss_G: 1.21
# [Epoch 29/50][Batch 240/300] Loss_D: 1.28 Loss_G: 0.66
# Epoch 29 running time: 2.76
# [Epoch 30/50][Batch 0/300] Loss_D: 1.31 Loss_G: 0.62
# [Epoch 30/50][Batch 60/300] Loss_D: 1.29 Loss_G: 0.84
# [Epoch 30/50][Batch 120/300] Loss_D: 1.34 Loss_G: 0.77
# [Epoch 30/50][Batch 180/300] Loss_D: 1.34 Loss_G: 0.78
# [Epoch 30/50][Batch 240/300] Loss_D: 1.36 Loss_G: 0.73
# Epoch 30 running time: 2.97
# [Epoch 31/50][Batch 0/300] Loss_D: 1.33 Loss_G: 0.79
# [Epoch 31/50][Batch 60/300] Loss_D: 1.43 Loss_G: 1.00
# [Epoch 31/50][Batch 120/300] Loss_D: 1.27 Loss_G: 0.88
# [Epoch 31/50][Batch 180/300] Loss_D: 1.36 Loss_G: 0.76
# [Epoch 31/50][Batch 240/300] Loss_D: 1.35 Loss_G: 0.77
# Epoch 31 running time: 2.95
# [Epoch 32/50][Batch 0/300] Loss_D: 1.31 Loss_G: 0.86
# [Epoch 32/50][Batch 60/300] Loss_D: 1.35 Loss_G: 0.68
# [Epoch 32/50][Batch 120/300] Loss_D: 1.35 Loss_G: 0.68
# [Epoch 32/50][Batch 180/300] Loss_D: 1.28 Loss_G: 0.81
# [Epoch 32/50][Batch 240/300] Loss_D: 1.33 Loss_G: 0.77
# Epoch 32 running time: 2.87
# [Epoch 33/50][Batch 0/300] Loss_D: 1.33 Loss_G: 0.82
# [Epoch 33/50][Batch 60/300] Loss_D: 1.42 Loss_G: 0.75
# [Epoch 33/50][Batch 120/300] Loss_D: 1.36 Loss_G: 0.98
# [Epoch 33/50][Batch 180/300] Loss_D: 1.36 Loss_G: 1.11
# [Epoch 33/50][Batch 240/300] Loss_D: 1.30 Loss_G: 0.76
# Epoch 33 running time: 2.91
# [Epoch 34/50][Batch 0/300] Loss_D: 1.31 Loss_G: 0.90
# [Epoch 34/50][Batch 60/300] Loss_D: 1.33 Loss_G: 0.76
# [Epoch 34/50][Batch 120/300] Loss_D: 1.35 Loss_G: 0.65
# [Epoch 34/50][Batch 180/300] Loss_D: 1.37 Loss_G: 0.81
# [Epoch 34/50][Batch 240/300] Loss_D: 1.33 Loss_G: 0.77
# Epoch 34 running time: 2.94
# [Epoch 35/50][Batch 0/300] Loss_D: 1.33 Loss_G: 0.73
# [Epoch 35/50][Batch 60/300] Loss_D: 1.34 Loss_G: 0.78
# [Epoch 35/50][Batch 120/300] Loss_D: 1.30 Loss_G: 0.92
# [Epoch 35/50][Batch 180/300] Loss_D: 1.37 Loss_G: 0.81
# [Epoch 35/50][Batch 240/300] Loss_D: 1.34 Loss_G: 0.84
# Epoch 35 running time: 2.94
# [Epoch 36/50][Batch 0/300] Loss_D: 1.35 Loss_G: 0.93
# [Epoch 36/50][Batch 60/300] Loss_D: 1.61 Loss_G: 0.89
# [Epoch 36/50][Batch 120/300] Loss_D: 1.32 Loss_G: 0.74
# [Epoch 36/50][Batch 180/300] Loss_D: 1.26 Loss_G: 0.69
# [Epoch 36/50][Batch 240/300] Loss_D: 1.30 Loss_G: 0.88
# Epoch 36 running time: 2.95
# [Epoch 37/50][Batch 0/300] Loss_D: 1.34 Loss_G: 0.77
# [Epoch 37/50][Batch 60/300] Loss_D: 1.37 Loss_G: 0.88
# [Epoch 37/50][Batch 120/300] Loss_D: 1.26 Loss_G: 0.78
# [Epoch 37/50][Batch 180/300] Loss_D: 1.43 Loss_G: 0.69
# [Epoch 37/50][Batch 240/300] Loss_D: 1.29 Loss_G: 0.82
# Epoch 37 running time: 2.90
# [Epoch 38/50][Batch 0/300] Loss_D: 1.31 Loss_G: 1.24
# [Epoch 38/50][Batch 60/300] Loss_D: 1.67 Loss_G: 1.63
# [Epoch 38/50][Batch 120/300] Loss_D: 1.36 Loss_G: 0.68
# [Epoch 38/50][Batch 180/300] Loss_D: 1.32 Loss_G: 0.83
# [Epoch 38/50][Batch 240/300] Loss_D: 1.38 Loss_G: 0.88
# Epoch 38 running time: 2.81
# [Epoch 39/50][Batch 0/300] Loss_D: 1.32 Loss_G: 0.92
# [Epoch 39/50][Batch 60/300] Loss_D: 1.37 Loss_G: 1.12
# [Epoch 39/50][Batch 120/300] Loss_D: 1.51 Loss_G: 0.78
# [Epoch 39/50][Batch 180/300] Loss_D: 1.24 Loss_G: 0.89
# [Epoch 39/50][Batch 240/300] Loss_D: 1.38 Loss_G: 0.72
# Epoch 39 running time: 2.84
# [Epoch 40/50][Batch 0/300] Loss_D: 1.24 Loss_G: 0.84
# [Epoch 40/50][Batch 60/300] Loss_D: 1.36 Loss_G: 0.71
# [Epoch 40/50][Batch 120/300] Loss_D: 1.36 Loss_G: 0.81
# [Epoch 40/50][Batch 180/300] Loss_D: 1.32 Loss_G: 0.80
# [Epoch 40/50][Batch 240/300] Loss_D: 1.44 Loss_G: 0.94
# Epoch 40 running time: 2.89
# [Epoch 41/50][Batch 0/300] Loss_D: 1.34 Loss_G: 0.76
# [Epoch 41/50][Batch 60/300] Loss_D: 1.34 Loss_G: 0.68
# [Epoch 41/50][Batch 120/300] Loss_D: 1.41 Loss_G: 1.32
# [Epoch 41/50][Batch 180/300] Loss_D: 1.30 Loss_G: 0.87
# [Epoch 41/50][Batch 240/300] Loss_D: 1.42 Loss_G: 1.07
# Epoch 41 running time: 2.64
# [Epoch 42/50][Batch 0/300] Loss_D: 1.24 Loss_G: 0.85
# [Epoch 42/50][Batch 60/300] Loss_D: 1.33 Loss_G: 0.81
# [Epoch 42/50][Batch 120/300] Loss_D: 1.41 Loss_G: 0.96
# [Epoch 42/50][Batch 180/300] Loss_D: 1.26 Loss_G: 0.96
# [Epoch 42/50][Batch 240/300] Loss_D: 1.41 Loss_G: 0.81
# Epoch 42 running time: 2.93
# [Epoch 43/50][Batch 0/300] Loss_D: 1.33 Loss_G: 0.77
# [Epoch 43/50][Batch 60/300] Loss_D: 1.37 Loss_G: 1.05
# [Epoch 43/50][Batch 120/300] Loss_D: 1.30 Loss_G: 0.92
# [Epoch 43/50][Batch 180/300] Loss_D: 1.34 Loss_G: 0.80
# [Epoch 43/50][Batch 240/300] Loss_D: 1.30 Loss_G: 0.89
# Epoch 43 running time: 2.92
# [Epoch 44/50][Batch 0/300] Loss_D: 1.38 Loss_G: 0.62
# [Epoch 44/50][Batch 60/300] Loss_D: 1.39 Loss_G: 0.80
# [Epoch 44/50][Batch 120/300] Loss_D: 1.29 Loss_G: 0.90
# [Epoch 44/50][Batch 180/300] Loss_D: 1.33 Loss_G: 0.73
# [Epoch 44/50][Batch 240/300] Loss_D: 1.34 Loss_G: 0.78
# Epoch 44 running time: 3.05
# [Epoch 45/50][Batch 0/300] Loss_D: 1.32 Loss_G: 0.83
# [Epoch 45/50][Batch 60/300] Loss_D: 1.28 Loss_G: 0.83
# [Epoch 45/50][Batch 120/300] Loss_D: 1.32 Loss_G: 0.90
# [Epoch 45/50][Batch 180/300] Loss_D: 1.28 Loss_G: 0.89
# [Epoch 45/50][Batch 240/300] Loss_D: 1.25 Loss_G: 1.10
# Epoch 45 running time: 2.88
# [Epoch 46/50][Batch 0/300] Loss_D: 1.28 Loss_G: 0.78
# [Epoch 46/50][Batch 60/300] Loss_D: 1.25 Loss_G: 0.81
# [Epoch 46/50][Batch 120/300] Loss_D: 1.30 Loss_G: 0.86
# [Epoch 46/50][Batch 180/300] Loss_D: 1.29 Loss_G: 0.89
# [Epoch 46/50][Batch 240/300] Loss_D: 1.31 Loss_G: 0.76
# Epoch 46 running time: 2.84
# [Epoch 47/50][Batch 0/300] Loss_D: 1.29 Loss_G: 0.82
# [Epoch 47/50][Batch 60/300] Loss_D: 1.30 Loss_G: 0.87
# [Epoch 47/50][Batch 120/300] Loss_D: 1.28 Loss_G: 0.88
# [Epoch 47/50][Batch 180/300] Loss_D: 1.32 Loss_G: 1.06
# [Epoch 47/50][Batch 240/300] Loss_D: 1.30 Loss_G: 0.74
# Epoch 47 running time: 2.87
# [Epoch 48/50][Batch 0/300] Loss_D: 1.32 Loss_G: 0.83
# [Epoch 48/50][Batch 60/300] Loss_D: 1.25 Loss_G: 1.07
# [Epoch 48/50][Batch 120/300] Loss_D: 1.34 Loss_G: 0.80
# [Epoch 48/50][Batch 180/300] Loss_D: 1.31 Loss_G: 1.05
# [Epoch 48/50][Batch 240/300] Loss_D: 1.30 Loss_G: 0.84
# Epoch 48 running time: 2.78
# [Epoch 49/50][Batch 0/300] Loss_D: 1.32 Loss_G: 0.81
# [Epoch 49/50][Batch 60/300] Loss_D: 1.32 Loss_G: 0.86
# [Epoch 49/50][Batch 120/300] Loss_D: 1.28 Loss_G: 0.85
# [Epoch 49/50][Batch 180/300] Loss_D: 1.34 Loss_G: 0.85
# [Epoch 49/50][Batch 240/300] Loss_D: 1.33 Loss_G: 0.79
# Epoch 49 running time: 3.06
# Total running time: 145.19s

# %%
plt.figure(figsize=(8,3))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(trainer.g_losses,label="G")
plt.plot(trainer.d_losses,label="D")

plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.savefig(os.path.join(output_root, data_name, 'g_d_loss.png'))
plt.show()

# %%
gif_generator(image_dir=os.path.join(output_root, data_name), 
              name_pattern=r'fake_samples_epoch_[\d]+|.png')

# %%
image_sample_dir = 'samples'

fake_name = os.path.join(data_name, 'cGAN')

if not os.path.exists(os.path.join(image_sample_dir, fake_name)):
    os.makedirs(os.path.join(image_sample_dir, fake_name))

image_path = os.path.join(image_sample_dir, fake_name, 'img{:04}.png')


# switch to eval mode
netG.eval()

for i in range(2048):
    noise = torch.randn(1, noize_dim, 
                        dtype=dtype, device=device,
                        requires_grad=False)
    y = torch.randint(10, (1,), device=device, requires_grad=False)
    img = netG(noise, y)
    vutils.save_image(img, image_path.format(i), 
                      normalize=True, range=(0,1))
