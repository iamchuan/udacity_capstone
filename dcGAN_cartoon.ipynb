# %% [markdown]
# ## Libraries

# %%
import sys
sys.path.append('./venv/lib/python3.6/site-packages')

# %%
import os
import time
import random

import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image

# %%
import torch
from torch import nn
from torch import optim
from torchvision import transforms as vtransforms
from torchvision import utils as vutils
from torchvision import datasets

# %%
from gans.utils.data import CartoonSet
from gans.utils.layers import *
from gans.utils.functions import *
from gans.models.model import *
from gans.trainer import *

# %% [markdown]
# ## Random seed

# %%
# Set random seem for reproducibility
manualSeed = 999
#manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)
# Out:
# Random Seed:  999

# %% [markdown]
# ## Inputs

# %%
# Dataset
data_root = './datasets'
data_name = 'CartoonSet'
# data_name = 'FashionMNIST'
# data_name = 'MNIST'

batch_size = 100
nrow = 10

num_epochs = 50

num_workers = 8


# Output dir
output_root = './output/dcGAN'
# overwrite real sample output
overwrite_real = False

noize_dim = 100

# Optimization parameters
lr = 0.001
beta1 = 0.5

# %% [markdown]
# ## Device

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

print('using device: ', device)
# Out:
# using device:  cuda:1

# %% [markdown]
# ## Dataset

# %%
img_size = 28
in_channels = 1

if data_name == 'CartoonSet':
    img_size = 75
    dataset = CartoonSet(root=os.path.join(data_root, data_name), 
                         transform=vtransforms.Compose([
                             vtransforms.CenterCrop(size=400),
                             vtransforms.Resize(size=img_size), 
                             vtransforms.ToTensor(),
                             vtransforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5)),
                         ]))
    
elif data_name == 'MNIST':
    dataset = datasets.MNIST(root=os.path.join(data_root, data_name), 
                             download=True,
                             transform=vtransforms.Compose([
                                 vtransforms.ToTensor(),
                                 vtransforms.Normalize((0.5,), (0.5,)),
                         ]))
elif data_name == 'FashionMNIST':
    dataset = datasets.FashionMNIST(root=os.path.join(data_root, data_name), 
                                    download=True,
                                    transform=vtransforms.Compose([
                                        vtransforms.ToTensor(),
                                        vtransforms.Normalize((0.5,), (0.5,)),
                                    ]))
    
dtype = dataset[0][0].dtype
img_shape = dataset[0][0].shape

# %% [markdown]
# ## Dataloader

# %%
dataloader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         shuffle=True, 
                                         num_workers=num_workers)

# %%
if not os.path.exists(os.path.join(output_root, data_name)):
    os.makedirs(os.path.join(output_root, data_name))

real_sample_path = os.path.join(output_root, data_name, 'real_samples.png')


real_batch = next(iter(dataloader))

vutils.save_image(real_batch[0], real_sample_path, 
                  normalize=True, range=(0,1), nrow=nrow)
Image(real_sample_path)

# %% [markdown]
# ## Model

# %%
netG = DCGenerator(img_shape=img_shape, noize_dim=noize_dim).to(device)
print(netG)
# Out:
# DCGenerator(
#   (model): Sequential(
#     (0): Unflatten2d(img_shape=(100, 1, 1))
#     (1): ConvTranspose2d(100, 256, kernel_size=(4, 4), stride=(1, 1))
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace)
#     (4): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(2, 2), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace)
#     (7): ConvTranspose2d(128, 64, kernel_size=(5, 5), stride=(2, 2), padding=(1, 1))
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace)
#     (10): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (11): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace)
#     (13): ConvTranspose2d(32, 3, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (14): Tanh()
#   )
# )

# %%
netD = DCDiscriminator(img_shape=img_shape).to(device)
print(netD)
# Out:
# DCDiscriminator(
#   (model): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1, inplace)
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.1, inplace)
#     (5): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(1, 1))
#     (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.1, inplace)
#     (8): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2), padding=(1, 1))
#     (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.1, inplace)
#     (11): Conv2d(256, 1, kernel_size=(4, 4), stride=(1, 1))
#     (12): Sigmoid()
#     (13): Flatten()
#   )
# )

# %%
C, H, W = img_shape
features = C * H * W

# %%
ngf = 32

layersG = [
    nn.ConvTranspose2d(noize_dim, ngf * 8, 4, 1, 0),
    nn.BatchNorm2d(ngf * 8),
    nn.ReLU(True),
    nn.ConvTranspose2d(ngf * 8, ngf * 4, 5, 2, 1),
    nn.BatchNorm2d(ngf * 4),
    nn.ReLU(True),
    nn.ConvTranspose2d(ngf * 4, ngf * 2, 5, 2, 1),
    nn.BatchNorm2d(ngf * 2),
    nn.ReLU(True),
    nn.ConvTranspose2d(ngf * 2, ngf, 4, 2, 1),
    nn.BatchNorm2d(ngf),
    nn.ReLU(True),
    nn.ConvTranspose2d(ngf, C, 3, 2, 1),
    nn.Tanh()
]

netG = DCGenerator(layers=layersG, noize_dim=noize_dim).to(device)
print(netG)

# %%
ndf = 32

layersD = [
    nn.Conv2d(C, ndf, 3, 2, 1),
    nn.LeakyReLU(0.1, inplace=True),
    nn.Conv2d(ndf, ndf * 2, 4, 2, 1),
    nn.BatchNorm2d(ndf * 2),
    nn.LeakyReLU(0.1, inplace=True),
    nn.Conv2d(ndf * 2, ndf * 4, 5, 2, 1),
    nn.BatchNorm2d(ndf * 4),
    nn.LeakyReLU(0.1, inplace=True),
    nn.Conv2d(ndf * 4, ndf * 8, 5, 2, 1),
    nn.BatchNorm2d(ndf * 8),
    nn.LeakyReLU(0.1, inplace=True),
    nn.Conv2d(ndf * 8, 1, 4, 1, 0),
    nn.Sigmoid()
]

netD = DCDiscriminator(layers=layersD).to(device)
print(netD)

# %% [markdown]
# ## Training

# %%
trainer = GANTrainer(generator=netG, discriminator=netD,
                     optimizer=optim.Adam, loss=nn.BCELoss(), 
                     device=device, multi_gpu=False, output_path=os.path.join(output_root, data_name),
                     batch_size=batch_size, num_epochs=num_epochs)

# %%
trainer.train(dataloader=dataloader, nrow=nrow)
# Out:
# /home/shu/.local/lib/python3.6/site-packages/torch/nn/functional.py:2016: UserWarning: Using a target size (torch.Size([100])) that is different to the input size (torch.Size([100, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# [Epoch 0/50][Batch 0/100] Loss_D: 1.80 Loss_G: 10.41
# [Epoch 0/50][Batch 20/100] Loss_D: 1.54 Loss_G: 15.98
# [Epoch 0/50][Batch 40/100] Loss_D: 0.12 Loss_G: 9.45
# [Epoch 0/50][Batch 60/100] Loss_D: 0.11 Loss_G: 4.55
# [Epoch 0/50][Batch 80/100] Loss_D: 0.05 Loss_G: 7.52
# Epoch 0 running time: 8.11
# [Epoch 1/50][Batch 0/100] Loss_D: 0.56 Loss_G: 0.79
# [Epoch 1/50][Batch 20/100] Loss_D: 0.09 Loss_G: 5.04
# [Epoch 1/50][Batch 40/100] Loss_D: 1.82 Loss_G: 12.09
# [Epoch 1/50][Batch 60/100] Loss_D: 1.40 Loss_G: 5.24
# [Epoch 22/50][Batch 80/100] Loss_D: 0.07 Loss_G: 5.49
# Epoch 22 running time: 8.70
# [Epoch 23/50][Batch 0/100] Loss_D: 0.06 Loss_G: 5.44
# [Epoch 23/50][Batch 20/100] Loss_D: 0.04 Loss_G: 5.03
# [Epoch 23/50][Batch 40/100] Loss_D: 0.34 Loss_G: 7.58
# [Epoch 23/50][Batch 60/100] Loss_D: 0.12 Loss_G: 5.85
# [Epoch 23/50][Batch 80/100] Loss_D: 0.11 Loss_G: 4.21
# Epoch 23 running time: 8.53
# [Epoch 24/50][Batch 0/100] Loss_D: 0.13 Loss_G: 4.87
# [Epoch 24/50][Batch 20/100] Loss_D: 0.02 Loss_G: 6.60
# [Epoch 24/50][Batch 40/100] Loss_D: 0.05 Loss_G: 6.08
# [Epoch 24/50][Batch 60/100] Loss_D: 0.07 Loss_G: 6.35
# [Epoch 24/50][Batch 80/100] Loss_D: 0.04 Loss_G: 6.23
# Epoch 24 running time: 8.81
# [Epoch 25/50][Batch 0/100] Loss_D: 0.26 Loss_G: 5.55
# [Epoch 25/50][Batch 20/100] Loss_D: 0.06 Loss_G: 5.15
# [Epoch 25/50][Batch 40/100] Loss_D: 0.05 Loss_G: 4.89
# [Epoch 25/50][Batch 60/100] Loss_D: 0.04 Loss_G: 5.98
# [Epoch 25/50][Batch 80/100] Loss_D: 0.06 Loss_G: 4.62
# Epoch 25 running time: 8.66
# [Epoch 26/50][Batch 0/100] Loss_D: 0.02 Loss_G: 6.94
# [Epoch 26/50][Batch 20/100] Loss_D: 0.51 Loss_G: 3.36
# [Epoch 26/50][Batch 40/100] Loss_D: 0.07 Loss_G: 5.55
# [Epoch 26/50][Batch 60/100] Loss_D: 0.12 Loss_G: 4.10
# [Epoch 26/50][Batch 80/100] Loss_D: 0.08 Loss_G: 4.81
# Epoch 26 running time: 8.43
# [Epoch 27/50][Batch 0/100] Loss_D: 0.04 Loss_G: 4.60
# [Epoch 27/50][Batch 20/100] Loss_D: 0.13 Loss_G: 5.48
# [Epoch 27/50][Batch 40/100] Loss_D: 0.04 Loss_G: 5.32
# [Epoch 27/50][Batch 60/100] Loss_D: 0.02 Loss_G: 5.79
# [Epoch 27/50][Batch 80/100] Loss_D: 0.10 Loss_G: 2.47
# Epoch 27 running time: 8.25
# [Epoch 28/50][Batch 0/100] Loss_D: 0.22 Loss_G: 5.69
# [Epoch 28/50][Batch 20/100] Loss_D: 0.15 Loss_G: 4.92
# [Epoch 28/50][Batch 40/100] Loss_D: 0.33 Loss_G: 8.07
# [Epoch 28/50][Batch 60/100] Loss_D: 0.08 Loss_G: 6.22
# [Epoch 28/50][Batch 80/100] Loss_D: 0.14 Loss_G: 3.47
# Epoch 28 running time: 8.26
# [Epoch 29/50][Batch 0/100] Loss_D: 0.04 Loss_G: 4.92
# [Epoch 29/50][Batch 20/100] Loss_D: 0.10 Loss_G: 6.70
# [Epoch 29/50][Batch 40/100] Loss_D: 0.06 Loss_G: 4.72
# [Epoch 29/50][Batch 60/100] Loss_D: 0.13 Loss_G: 3.52
# [Epoch 29/50][Batch 80/100] Loss_D: 0.05 Loss_G: 4.82
# Epoch 29 running time: 8.17
# [Epoch 30/50][Batch 0/100] Loss_D: 0.04 Loss_G: 6.21
# [Epoch 30/50][Batch 20/100] Loss_D: 0.01 Loss_G: 7.55
# [Epoch 30/50][Batch 40/100] Loss_D: 0.19 Loss_G: 8.33
# [Epoch 30/50][Batch 60/100] Loss_D: 0.26 Loss_G: 11.30
# [Epoch 30/50][Batch 80/100] Loss_D: 0.17 Loss_G: 6.87
# Epoch 30 running time: 8.27
# [Epoch 31/50][Batch 0/100] Loss_D: 0.06 Loss_G: 5.10
# [Epoch 31/50][Batch 20/100] Loss_D: 0.05 Loss_G: 4.97
# [Epoch 31/50][Batch 40/100] Loss_D: 0.04 Loss_G: 4.70
# [Epoch 31/50][Batch 60/100] Loss_D: 0.06 Loss_G: 5.55
# [Epoch 31/50][Batch 80/100] Loss_D: 0.03 Loss_G: 5.24
# Epoch 31 running time: 8.28
# [Epoch 32/50][Batch 0/100] Loss_D: 0.03 Loss_G: 6.92
# [Epoch 32/50][Batch 20/100] Loss_D: 0.05 Loss_G: 3.95
# [Epoch 32/50][Batch 40/100] Loss_D: 0.21 Loss_G: 6.09
# [Epoch 32/50][Batch 60/100] Loss_D: 0.17 Loss_G: 3.73
# [Epoch 32/50][Batch 80/100] Loss_D: 0.03 Loss_G: 4.51
# Epoch 32 running time: 8.31
# [Epoch 33/50][Batch 0/100] Loss_D: 0.04 Loss_G: 5.94
# [Epoch 33/50][Batch 20/100] Loss_D: 0.42 Loss_G: 4.56
# [Epoch 33/50][Batch 40/100] Loss_D: 0.03 Loss_G: 6.69
# [Epoch 33/50][Batch 60/100] Loss_D: 0.18 Loss_G: 6.44
# [Epoch 33/50][Batch 80/100] Loss_D: 0.03 Loss_G: 5.84
# Epoch 33 running time: 8.32
# [Epoch 34/50][Batch 0/100] Loss_D: 0.02 Loss_G: 5.47
# [Epoch 34/50][Batch 20/100] Loss_D: 0.02 Loss_G: 5.77
# [Epoch 34/50][Batch 40/100] Loss_D: 0.03 Loss_G: 5.51
# [Epoch 34/50][Batch 60/100] Loss_D: 0.04 Loss_G: 4.89
# [Epoch 34/50][Batch 80/100] Loss_D: 0.15 Loss_G: 9.73
# Epoch 34 running time: 8.31
# [Epoch 35/50][Batch 0/100] Loss_D: 0.03 Loss_G: 5.87
# [Epoch 35/50][Batch 20/100] Loss_D: 0.25 Loss_G: 8.39
# [Epoch 35/50][Batch 40/100] Loss_D: 0.11 Loss_G: 6.20
# [Epoch 35/50][Batch 60/100] Loss_D: 0.07 Loss_G: 5.18
# [Epoch 35/50][Batch 80/100] Loss_D: 0.03 Loss_G: 4.76
# Epoch 35 running time: 8.33
# [Epoch 36/50][Batch 0/100] Loss_D: 0.05 Loss_G: 5.97
# [Epoch 36/50][Batch 20/100] Loss_D: 0.05 Loss_G: 7.81
# [Epoch 36/50][Batch 40/100] Loss_D: 0.06 Loss_G: 4.42
# [Epoch 36/50][Batch 60/100] Loss_D: 0.02 Loss_G: 6.53
# [Epoch 36/50][Batch 80/100] Loss_D: 0.02 Loss_G: 5.29
# Epoch 36 running time: 8.20
# [Epoch 37/50][Batch 0/100] Loss_D: 0.13 Loss_G: 7.75
# [Epoch 37/50][Batch 20/100] Loss_D: 0.03 Loss_G: 5.40
# [Epoch 37/50][Batch 40/100] Loss_D: 0.62 Loss_G: 12.97
# [Epoch 37/50][Batch 60/100] Loss_D: 0.17 Loss_G: 7.90
# [Epoch 37/50][Batch 80/100] Loss_D: 0.21 Loss_G: 3.76
# Epoch 37 running time: 8.31
# [Epoch 38/50][Batch 0/100] Loss_D: 0.60 Loss_G: 16.41
# [Epoch 38/50][Batch 20/100] Loss_D: 0.09 Loss_G: 6.57
# [Epoch 38/50][Batch 40/100] Loss_D: 0.05 Loss_G: 5.87
# [Epoch 38/50][Batch 60/100] Loss_D: 0.05 Loss_G: 4.63
# [Epoch 38/50][Batch 80/100] Loss_D: 0.04 Loss_G: 5.74
# Epoch 38 running time: 8.22
# [Epoch 39/50][Batch 0/100] Loss_D: 0.07 Loss_G: 4.54
# [Epoch 39/50][Batch 20/100] Loss_D: 0.03 Loss_G: 5.65
# [Epoch 39/50][Batch 40/100] Loss_D: 0.02 Loss_G: 7.23
# [Epoch 39/50][Batch 60/100] Loss_D: 1.06 Loss_G: 8.60
# [Epoch 39/50][Batch 80/100] Loss_D: 0.07 Loss_G: 4.92
# Epoch 39 running time: 8.25
# [Epoch 40/50][Batch 0/100] Loss_D: 0.07 Loss_G: 4.49
# [Epoch 40/50][Batch 20/100] Loss_D: 0.03 Loss_G: 5.23
# [Epoch 40/50][Batch 40/100] Loss_D: 0.04 Loss_G: 5.53
# [Epoch 40/50][Batch 60/100] Loss_D: 0.03 Loss_G: 5.25
# [Epoch 40/50][Batch 80/100] Loss_D: 0.09 Loss_G: 3.75
# Epoch 40 running time: 8.26
# [Epoch 41/50][Batch 0/100] Loss_D: 0.11 Loss_G: 4.28
# [Epoch 41/50][Batch 20/100] Loss_D: 0.02 Loss_G: 5.23
# [Epoch 41/50][Batch 40/100] Loss_D: 0.09 Loss_G: 5.76
# [Epoch 41/50][Batch 60/100] Loss_D: 0.02 Loss_G: 5.53
# [Epoch 41/50][Batch 80/100] Loss_D: 0.04 Loss_G: 4.80
# Epoch 41 running time: 8.32
# [Epoch 42/50][Batch 0/100] Loss_D: 0.05 Loss_G: 5.86
# [Epoch 42/50][Batch 20/100] Loss_D: 0.10 Loss_G: 7.76
# [Epoch 42/50][Batch 40/100] Loss_D: 0.18 Loss_G: 10.32
# [Epoch 42/50][Batch 60/100] Loss_D: 0.09 Loss_G: 6.55
# [Epoch 42/50][Batch 80/100] Loss_D: 0.02 Loss_G: 6.28
# Epoch 42 running time: 8.27
# [Epoch 43/50][Batch 0/100] Loss_D: 0.04 Loss_G: 5.16
# [Epoch 43/50][Batch 20/100] Loss_D: 0.02 Loss_G: 6.79
# [Epoch 43/50][Batch 40/100] Loss_D: 0.05 Loss_G: 4.78
# [Epoch 43/50][Batch 60/100] Loss_D: 0.02 Loss_G: 5.49
# [Epoch 43/50][Batch 80/100] Loss_D: 0.07 Loss_G: 4.10
# Epoch 43 running time: 8.28
# [Epoch 44/50][Batch 0/100] Loss_D: 0.01 Loss_G: 6.19
# [Epoch 44/50][Batch 20/100] Loss_D: 0.09 Loss_G: 11.01
# [Epoch 44/50][Batch 40/100] Loss_D: 0.07 Loss_G: 8.67
# [Epoch 44/50][Batch 60/100] Loss_D: 0.03 Loss_G: 6.15
# [Epoch 44/50][Batch 80/100] Loss_D: 0.04 Loss_G: 5.64
# Epoch 44 running time: 8.33
# [Epoch 45/50][Batch 0/100] Loss_D: 0.04 Loss_G: 5.22
# [Epoch 45/50][Batch 20/100] Loss_D: 0.97 Loss_G: 12.23
# [Epoch 45/50][Batch 40/100] Loss_D: 0.17 Loss_G: 4.57
# [Epoch 45/50][Batch 60/100] Loss_D: 0.05 Loss_G: 5.62
# [Epoch 45/50][Batch 80/100] Loss_D: 0.03 Loss_G: 5.44
# Epoch 45 running time: 8.26
# [Epoch 46/50][Batch 0/100] Loss_D: 0.03 Loss_G: 5.58
# [Epoch 46/50][Batch 20/100] Loss_D: 0.03 Loss_G: 6.19
# [Epoch 46/50][Batch 40/100] Loss_D: 0.03 Loss_G: 6.74
# [Epoch 46/50][Batch 60/100] Loss_D: 0.02 Loss_G: 5.96
# [Epoch 46/50][Batch 80/100] Loss_D: 0.05 Loss_G: 4.48
# Epoch 46 running time: 8.22
# [Epoch 47/50][Batch 0/100] Loss_D: 0.05 Loss_G: 5.01
# [Epoch 47/50][Batch 20/100] Loss_D: 0.01 Loss_G: 5.73
# [Epoch 47/50][Batch 40/100] Loss_D: 0.02 Loss_G: 5.78
# [Epoch 47/50][Batch 60/100] Loss_D: 0.01 Loss_G: 6.15
# [Epoch 47/50][Batch 80/100] Loss_D: 0.01 Loss_G: 5.65
# Epoch 47 running time: 8.29
# [Epoch 48/50][Batch 0/100] Loss_D: 0.01 Loss_G: 6.06
# [Epoch 48/50][Batch 20/100] Loss_D: 0.01 Loss_G: 5.85
# [Epoch 48/50][Batch 40/100] Loss_D: 0.02 Loss_G: 6.37
# [Epoch 48/50][Batch 60/100] Loss_D: 7.14 Loss_G: 2.30
# [Epoch 48/50][Batch 80/100] Loss_D: 0.07 Loss_G: 8.87
# Epoch 48 running time: 8.24
# [Epoch 49/50][Batch 0/100] Loss_D: 0.23 Loss_G: 8.53
# [Epoch 49/50][Batch 20/100] Loss_D: 0.05 Loss_G: 6.57
# [Epoch 49/50][Batch 40/100] Loss_D: 0.08 Loss_G: 5.82
# [Epoch 49/50][Batch 60/100] Loss_D: 0.06 Loss_G: 15.29
# [Epoch 49/50][Batch 80/100] Loss_D: 0.02 Loss_G: 7.50
# Epoch 49 running time: 8.23
# Total running time: 424.26s

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(trainer.g_losses,label="G")
plt.plot(trainer.d_losses,label="D")

plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.savefig(os.path.join(output_root, data_name, 'g_d_loss_linear_fashionMNIST.png'))
plt.show()

# %%
gif_generator(image_dir=os.path.join(output_root, data_name), 
              name_pattern=r'fake_samples_epoch_[\d]+|.png')
